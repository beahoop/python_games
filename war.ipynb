# %%
elif self.player1.card.value == self.player2.card.value:
                    self.player1.hand.append(self.player1.card)
                    self.player2.hand.append(self.player2.card)
                    #giving the cards back to the players 
                    print(f"WAR TIME!")
                    print(f"""
                    {self.player1.name} has {len(self.player1.hand)} and
                    {self.player2.name} has {len(self.player2.hand)} 
                    """)
                    self.player1.pot = self.player1.hand[:4]
                    print("PLAYER1 POT", self.player1.pot)
                    self.player1.hand = self.player1.hand[4:-4]
                    #taking 4 from player1 
                    self.player2.pot = self.player2.hand[:4]
                    print("PLAYER2 POT", self.player2.pot)
                    self.player2.hand = self.player2.hand[4:-4]
                    #taking 4 from player2
                    self.player1.card = self.player1.hand.pop()
                    #popping player 1 playing card off
                    self.player2.card = self.player2.hand.pop()
                    #popping player 2 playing card off
                    
                    
                    #if player1 wins war
                    if self.player1.card.value > self.player2.card.value:
                        print("BEFORE ANYTHING P1!", len(self.player2.hand))
                        print(f"{self.player1.name} wins war with {self.player1.card}!")
                        self.player1.hand.append(self.player1.card)
                        #giving player1 the card they just popped off - 1 card
                        self.player1.hand.append(self.player2.card)
                        #giving player1 the card player2 just popped off - 1 card
                        print(len(self.player1.pot), len(self.player2.pot), self.player1.pot+ self.player2.pot)
                        #these cards are not being added.  
                        print("BEFORE POT1!", len(self.player1.hand))
                        self.player1.hand.extend(self.player1.pot)
                        print("AFTER POT1!", len(self.player1.hand))
    
                        self.player1.hand.extend(self.player2.pot)
                        #adding the pots they won - 8 cards
                        
                        print(f"""
                        {self.player1.name} has {len(self.player1.hand)} and
                        {self.player2.name} has {len(self.player2.hand)} 
                        """)
                    else:
                        print(f"{self.player2.name} wins war with {self.player2.card}!")
                        print("BEFORE ANYTHING P2!", len(self.player2.hand))
                        self.player2.hand.append(self.player1.card)
                        #giving player2 the card player1 just popped off - 1 card
                        self.player2.hand.append(self.player2.card)
                        #giving player2 the card they just popped off - 1 card
                       
                        
                        print("BEFORE POT1!", len(self.player2.hand))
                        self.player2.hand.extend(self.player1.pot)
                        print("AFTER POT1!", len(self.player2.hand))
                        self.player2.hand.extend(self.player2.pot)
                        print("AFTER POT2!", len(self.player2.hand))
                        #giving player2 the pots of player1 and 2 - 8 cards
                        
                        print(f"""
                        {self.player1.name} has {len(self.player1.hand)} and
                        {self.player2.name} has {len(self.player2.hand)} 
                        """)
